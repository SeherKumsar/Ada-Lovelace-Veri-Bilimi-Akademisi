# %% [markdown]
# ## Grup Çalışması
# - Betül Uluocak
# - Leyla Tülü
# - Seher Kumsar
# - Neslihan Karaman

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# from matplotlib import colors as mcolors
# from matplotlib import patches as mpatches

# %%
base_url = "../data/"
data = base_url + "birds.csv"

# %%
birds = pd.read_csv(data)

# %%
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
family_counts = birds["Family"].value_counts()
print(family_counts)
print(type(family_counts))
# Out:
# Family
# Anatidae             45
# Parulidae            41
# Scolopacidae         34
# Laridae              28
# Passerellidae        26
# Tyrannidae           19
# Icteridae            15
# Accipitridae         15
# Fringillidae         13
# Picidae              12
# Turdidae             11
# Ardeidae             11
# Strigidae            11
# Cardinalidae         11
# Phasianidae           9
# Rallidae              8
# Columbidae            8
# Troglodytidae         7
# Hirundinidae          7
# Vireonidae            7
# Trochilidae           7
# Charadriidae          7
# Corvidae              6
# Podicipedidae         6
# Falconidae            6
# Calcariidae           5
# Mimidae               5
# Threskiornithidae     4
# Alcidae               4
# Caprimulgidae         4
# Gaviidae              4
# Stercorariidae        3
# Cuculidae             3
# Paridae               3
# Sittidae              3
# Pelecanidae           2
# Cathartidae           2
# Apodidae              2
# ...

# %%
family_counts = birds["Family"].value_counts()
# Seri -> Dataframe
family_counts_df = pd.DataFrame({'Family': family_counts.index, 'SpeciesCount': family_counts.values})
family_counts_df
# Out:
#                Family  SpeciesCount
# 0            Anatidae            45
# 1           Parulidae            41
# 2        Scolopacidae            34
# 3             Laridae            28
# 4       Passerellidae            26
# 5          Tyrannidae            19
# 6           Icteridae            15
# 7        Accipitridae            15
# 8        Fringillidae            13
# 9             Picidae            12
# 10           Turdidae            11
# 11           Ardeidae            11
# 12          Strigidae            11
# 13       Cardinalidae            11
# 14        Phasianidae             9
# 15           Rallidae             8
# 16         Columbidae             8
# 17      Troglodytidae             7
# 18       Hirundinidae             7
# 19         Vireonidae             7
# 20        Trochilidae             7
# 21       Charadriidae             7
# 22           Corvidae             6
# 23      Podicipedidae             6
# 24         Falconidae             6
# ...

# %%
family_counts = birds["Family"].value_counts()
# Seri -> Dataframe
family_counts_df = pd.DataFrame({'Family': family_counts.index, 'SpeciesCount': family_counts.values})

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Family', y='SpeciesCount', data=family_counts_df)
plt.xticks(rotation=90)
plt.xlabel('Family')
plt.ylabel('Number of Species')
plt.title('Number of Species per Family')
plt.show()

# %%
# plt.barh(y = birds["Family"].value_counts().sort_values(ascending=False).index, 
#          width =birds["Family"].value_counts().sort_values(ascending=False).values,
#          figure = plt.figure(figsize=(10, 10)))

# %%
plt.barh(y = birds["Family"].value_counts().sort_values(ascending=False).iloc[0:5].index, 
         width =birds["Family"].value_counts().sort_values(ascending=False).iloc[0:5].values)
# Out:
# <BarContainer object of 5 artists>

# %%
genus_max_wingspan_df = birds.groupby('Genus')['MaxWingspan'].max().reset_index()
genus_max_wingspan_df
# Out:
#               Genus  MaxWingspan
# 0          Acanthis         25.0
# 1         Accipiter        127.0
# 2           Actitis         40.0
# 3      Aechmophorus        102.0
# 4          Aegolius         62.0
# ..              ...          ...
# 233           Vireo         25.0
# 234  Xanthocephalus         44.0
# 235            Xema         87.0
# 236         Zenaida         58.0
# 237     Zonotrichia         27.0
#
# [238 rows x 2 columns]

# %%
#####cinsine göe max kanat uzunlukları ########
genus_max_wingspan_df = birds.groupby('Genus')['MaxWingspan'].max().reset_index()

# Plotting
plt.figure(figsize=(120, 90))
sns.barplot(x='Genus', y='MaxWingspan', data=genus_max_wingspan_df)
plt.xticks(rotation=90)
plt.xlabel('Kuş Cinsi')
plt.ylabel('Maksimum Kanat Uzunluğu')
plt.title('Kuş Cinsine Göre Maksimum Kanat Uzunluğu')
plt.show()

# %%
#Kuş Cinsine Göre Maksimum Kanat Uzunluğu 200 den büyük olanlar
genus_max_wingspan_df = birds.groupby('Genus')['MaxWingspan'].max().reset_index()
genus_max_wingspan_df = genus_max_wingspan_df[genus_max_wingspan_df['MaxWingspan'] > 100]
# Plotting
plt.figure(figsize=(12, 9))
sns.barplot(x='Genus', y='MaxWingspan', data=genus_max_wingspan_df)
plt.xticks(rotation=90)
plt.xlabel('Kuş Cinsi')
plt.ylabel('Maksimum Kanat Uzunluğu')
plt.title('Kuş Cinsine Göre Maksimum Kanat Uzunluğu')
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x = birds['Family'],
            y = birds['MinBodyMass']
            )

plt.xticks(rotation=90)
plt.xlabel('Family')
plt.ylabel('MinBodyMass')
plt.title('MinBodyMass per Family')
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x = birds['Family'],
            y = birds['ConservationStatus']
            )

plt.xticks(rotation=90)
plt.xlabel('Family')
plt.ylabel('ConservationStatus')
plt.title('ConservationStatus per Family')
plt.show()

# %%
# x='Family', y='ConservationStatus' sns.hisplot
plt.figure(figsize=(10, 6))
sns.histplot(data=birds, x='Family', y='ConservationStatus')
plt.xticks(rotation=90)
plt.xlabel('Family')
plt.ylabel('ConservationStatus')
plt.title('ConservationStatus per Family')
plt.show()
